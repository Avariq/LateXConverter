# %%
# !git clone https://github.com/ultralytics/ultralytics.git
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 10774, done.
# remote: Counting objects: 100% (540/540), done.
# remote: Compressing objects: 100% (254/254), done.
# remote: Total 10774 (delta 354), reused 430 (delta 286), pack-reused 10234
# Receiving objects: 100% (10774/10774), 6.55 MiB | 14.73 MiB/s, done.
# Resolving deltas: 100% (7346/7346), done.

# %%
# %cd ultralytics
# %pip install -qr requirements.txt  # install
# Out:
# /content/ultralytics

# %%
from google.colab import drive

drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !unzip '/content/drive/My Drive/AidaDSYolov8XS.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: AidaDSYolov8XS/train/labels/b74aa42a-cd0d-401f-9651-f0bd41981758.txt
#   inflating: AidaDSYolov8XS/train/labels/b74afe01-b97f-4f4f-9bdd-90ddb56b90ff.txt
#   inflating: AidaDSYolov8XS/train/labels/b74f780b-47d1-4977-b405-c7bbf16b9886.txt
#   inflating: AidaDSYolov8XS/train/labels/b75439c2-997d-4efe-bc62-1bbc7dc034d3.txt
#   inflating: AidaDSYolov8XS/train/labels/b75ac898-82be-48cf-abfb-619abfa0a7f1.txt
#   inflating: AidaDSYolov8XS/train/labels/b75d0bd8-2246-4ba0-8622-8da111560db6.txt
#   inflating: AidaDSYolov8XS/train/labels/b75f611b-2f39-4ff5-b2e2-4ce748dbc73c.txt
#   inflating: AidaDSYolov8XS/train/labels/b760dd4a-4ada-4751-a722-5892f08d51ac.txt
#   inflating: AidaDSYolov8XS/train/labels/b76b3227-c85a-441b-993f-c856e9a10124.txt
#   inflating: AidaDSYolov8XS/train/labels/b77350c8-3973-45a9-8331-5b0a8506ffed.txt
#   inflating: AidaDSYolov8XS/train/labels/b776e93f-02e1-43f7-9cdf-02554c848b12.txt
# ...

# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 595.4/595.4 kB 7.7 MB/s eta 0:00:00
# ...

# %%
# !yolo detect train data=/content/ultralytics/AidaDSYolov8XS/data.yaml model=/content/bestYolov8.pt epochs=12 imgsz=640 batch=52
# Out:
# Ultralytics YOLOv8.0.114 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo predict model=/content/bestYolov8.pt source=/content/Untitled.png
# Out:
# Ultralytics YOLOv8.0.114 🚀 Python-3.10.11 torch-2.0.1+cu118 CPU
# Model summary (fused): 168 layers, 11160801 parameters, 0 gradients
#
# image 1/1 /content/Untitled.png: 512x640 1 \left|, 1 c, 1 \lim_, 567.6ms
# Speed: 3.2ms preprocess, 567.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict5
